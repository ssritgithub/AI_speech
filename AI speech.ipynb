# %%
import pyttsx3 #pip install pyttsx3
import speech_recognition as sr #pip install speechRecognition
import datetime
import wikipedia #pip install wikipedia
import webbrowser
import os
import smtplib
import pyttsx3

engine = pyttsx3.init()
engine.say("I will speak this text")
engine.runAndWait()

print("Initializing Jarvis")
MASTER = "Aditya"

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)
#Speak function will speak/Pronounce the string which is passed to it
def speak(text):
    engine.say(text)
    engine.runAndWait()

#This funtion will wish you as per the current time
def wishMe():
    hour = int(datetime.datetime.now().hour)
    print(hour)

    if hour>=0 and hour <12:
        speak("good morning" + MASTER)

    elif hour>=12 and hour<18:
        speak("good afternoon" + MASTER)

    else:
        speak("good Evening" + MASTER)

    speak("i am your assistant. How may I help you?")

def sendEmail(to, content):
    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.ehlo()
    server.starttls()
    server.login('kumaraman.rose@gmail.ocm', 'password')
    server.sendmail("harry@gmail.com", to, content)
    server.close()

    



#This function will take command from the microphone
def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        audio = r.listen(source)

    try :
        print("Recognizing...")
        query = r.recognize_google(audio, language = 'en-in')
        print(f"user said: {query}\n")

    except Exception as e:
        print("Say that again please...")
        query = None

    return query

#main program starting
def main():
    speak("Initializing Jarvis...")
    wishMe()
    query = takeCommand()

    #Logic for executing tasks as per the query
    if 'wikipedia' in query.lower():
        speak('searching wikipedia...')
        query = query.replace("wikipedia", "")
        results = wikipedia.summary(query, sentences =2)
        print(results)
        speak(results)

    elif 'open youtube' in query.lower():
        #webbrowser.open('youtube.com')
        url = "youtube.com"
        chrome_path = 'c:/program Files (x86)/Google/Chrome/Application/chrome.exe %s'
        webbrowser.get(chrome_path).open(url)

    elif 'open google' in query.lower():
        #webbrowser.open('youtube.com')
        url = "google.com"
        chrome_path = 'c:/program Files (x86)/Google/Chrome/Application/chrome.exe %s'
        webbrowser.get(chrome_path).open(url)

    elif 'play music' in query.lower():
        songs_dir = "C:\\Users\\Dell\\Desktop\\Photos\\audio"
        songs = os.listdir(songs_dir)
        print(songs)
        os.startfile(os.path.join(songs_dir, songs[0]))

    elif 'the time' in query.lower():
        strTime = datetime.datetime.now().strftime("%H:%M:%S")
        speak(f"{MASTER} the time is {strTime}")

    elif 'open code' in query.lower():
        codePath = "C:\\Users\\Dell\\AppData\\Local\\Programs\\Microsoft VS Code\\Code.exe"
        os.startfile(codePath)
    
    elif 'email to raj' in query.lower():
        try:
            speak("what should i send")
            content = takeCommand()
            to = "harry@gmail.ocm"
            sendEmail(to, content)
            speak("Email has been sent to raj")
        except Exception as e:
            print(e)


main()
Initializing Jarvis
0
---------------------------------------------------------------------------
ModuleNotFoundError                       Traceback (most recent call last)
~\anaconda3\lib\site-packages\speech_recognition\__init__.py in get_pyaudio()
    107         try:
--> 108             import pyaudio
    109         except ImportError:

ModuleNotFoundError: No module named 'pyaudio'

During handling of the above exception, another exception occurred:

AttributeError                            Traceback (most recent call last)
~\AppData\Local\Temp/ipykernel_34892/2962947793.py in <module>
    120 
    121 
--> 122 main()

~\AppData\Local\Temp/ipykernel_34892/2962947793.py in main()
     73     speak("Initializing Jarvis...")
     74     wishMe()
---> 75     query = takeCommand()
     76 
     77     #Logic for executing tasks as per the query

~\AppData\Local\Temp/ipykernel_34892/2962947793.py in takeCommand()
     54 def takeCommand():
     55     r = sr.Recognizer()
---> 56     with sr.Microphone() as source:
     57         print("Listening...")
     58         audio = r.listen(source)

~\anaconda3\lib\site-packages\speech_recognition\__init__.py in __init__(self, device_index, sample_rate, chunk_size)
     77 
     78         # set up PyAudio
---> 79         self.pyaudio_module = self.get_pyaudio()
     80         audio = self.pyaudio_module.PyAudio()
     81         try:

~\anaconda3\lib\site-packages\speech_recognition\__init__.py in get_pyaudio()
    108             import pyaudio
    109         except ImportError:
--> 110             raise AttributeError("Could not find PyAudio; check installation")
    111         from distutils.version import LooseVersion
    112         if LooseVersion(pyaudio.__version__) < LooseVersion("0.2.11"):

AttributeError: Could not find PyAudio; check installation
pip install pyttsx3
Collecting pyttsx3
  Downloading pyttsx3-2.90-py3-none-any.whl (39 kB)
Requirement already satisfied: comtypes in c:\users\adity\anaconda3\lib\site-packages (from pyttsx3) (1.1.10)
Collecting pypiwin32
  Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
Requirement already satisfied: pywin32 in c:\users\adity\anaconda3\lib\site-packages (from pyttsx3) (228)
Installing collected packages: pypiwin32, pyttsx3
Successfully installed pypiwin32-223 pyttsx3-2.90
Note: you may need to restart the kernel to use updated packages.
pip install speechRecognition
Collecting speechRecognition
  Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
Installing collected packages: speechRecognition
Successfully installed speechRecognition-3.8.1
Note: you may need to restart the kernel to use updated packages.
pip install wikipedia
Collecting wikipedia
  Downloading wikipedia-1.4.0.tar.gz (27 kB)
Requirement already satisfied: beautifulsoup4 in c:\users\adity\anaconda3\lib\site-packages (from wikipedia) (4.10.0)
Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\adity\anaconda3\lib\site-packages (from wikipedia) (2.26.0)
Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\adity\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.7)
Requirement already satisfied: certifi>=2017.4.17 in c:\users\adity\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2021.10.8)
Note: you may need to restart the kernel to use updated packages.
Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\adity\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.4)
Requirement already satisfied: idna<4,>=2.5 in c:\users\adity\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.2)
Requirement already satisfied: soupsieve>1.2 in c:\users\adity\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.2.1)
Building wheels for collected packages: wikipedia
  Building wheel for wikipedia (setup.py): started
  Building wheel for wikipedia (setup.py): finished with status 'done'
  Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11696 sha256=4b7ebe0076dc1f99e12f0cc06d844f762bbd10c582287ea9d43c0154e7c9c672
  Stored in directory: c:\users\adity\appdata\local\pip\cache\wheels\c2\46\f4\caa1bee71096d7b0cdca2f2a2af45cacf35c5760bee8f00948
Successfully built wikipedia
Installing collected packages: wikipedia
Successfully installed wikipedia-1.4.0
import pyttsx3
engine = pyttsx3.init()
engine.say("I will speak this text")
engine.runAndWait()
import speech_recognition as sr
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)
Recognize speech input from the microphone
  File "C:\Users\adity\AppData\Local\Temp/ipykernel_31536/624013771.py", line 5
    Recognize speech input from the microphone
              ^
SyntaxError: invalid syntax
pip install PyAudio
Collecting PyAudio
  Downloading PyAudio-0.2.11.tar.gz (37 kB)
Building wheels for collected packages: PyAudio
  Building wheel for PyAudio (setup.py): started
  Building wheel for PyAudio (setup.py): finished with status 'error'
  Running setup.py clean for PyAudio
Failed to build PyAudio
Installing collected packages: PyAudio
    Running setup.py install for PyAudio: started
    Running setup.py install for PyAudio: finished with status 'error'
Note: you may need to restart the kernel to use updated packages.
  ERROR: Command errored out with exit status 1:
   command: 'C:\Users\adity\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\adity\\AppData\\Local\\Temp\\pip-install-fopr8r8d\\pyaudio_a38352715b6148bab3d99d2f32586d5e\\setup.py'"'"'; __file__='"'"'C:\\Users\\adity\\AppData\\Local\\Temp\\pip-install-fopr8r8d\\pyaudio_a38352715b6148bab3d99d2f32586d5e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\adity\AppData\Local\Temp\pip-wheel-sgo8m__y'
       cwd: C:\Users\adity\AppData\Local\Temp\pip-install-fopr8r8d\pyaudio_a38352715b6148bab3d99d2f32586d5e\
  Complete output (9 lines):
  running bdist_wheel
  running build
  running build_py
  creating build
  creating build\lib.win-amd64-3.9
  copying src\pyaudio.py -> build\lib.win-amd64-3.9
  running build_ext
  building '_portaudio' extension
  error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
  ----------------------------------------
  ERROR: Failed building wheel for PyAudio
    ERROR: Command errored out with exit status 1:
     command: 'C:\Users\adity\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\adity\\AppData\\Local\\Temp\\pip-install-fopr8r8d\\pyaudio_a38352715b6148bab3d99d2f32586d5e\\setup.py'"'"'; __file__='"'"'C:\\Users\\adity\\AppData\\Local\\Temp\\pip-install-fopr8r8d\\pyaudio_a38352715b6148bab3d99d2f32586d5e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\adity\AppData\Local\Temp\pip-record-7b5u2r0c\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\adity\anaconda3\Include\PyAudio'
         cwd: C:\Users\adity\AppData\Local\Temp\pip-install-fopr8r8d\pyaudio_a38352715b6148bab3d99d2f32586d5e\
    Complete output (9 lines):
    running install
    running build
    running build_py
    creating build
    creating build\lib.win-amd64-3.9
    copying src\pyaudio.py -> build\lib.win-amd64-3.9
    running build_ext
    building '_portaudio' extension
    error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
    ----------------------------------------
ERROR: Command errored out with exit status 1: 'C:\Users\adity\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\adity\\AppData\\Local\\Temp\\pip-install-fopr8r8d\\pyaudio_a38352715b6148bab3d99d2f32586d5e\\setup.py'"'"'; __file__='"'"'C:\\Users\\adity\\AppData\\Local\\Temp\\pip-install-fopr8r8d\\pyaudio_a38352715b6148bab3d99d2f32586d5e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\adity\AppData\Local\Temp\pip-record-7b5u2r0c\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\adity\anaconda3\Include\PyAudio' Check the logs for full command output.
pip install wolframalpha
Collecting wolframalpha
  Downloading wolframalpha-5.0.0-py3-none-any.whl (7.5 kB)
Requirement already satisfied: more-itertools in c:\users\adity\anaconda3\lib\site-packages (from wolframalpha) (8.10.0)
Collecting jaraco.context
  Downloading jaraco.context-4.1.1-py3-none-any.whl (4.4 kB)
Requirement already satisfied: xmltodict in c:\users\adity\anaconda3\lib\site-packages (from wolframalpha) (0.12.0)
Installing collected packages: jaraco.context, wolframalpha
Successfully installed jaraco.context-4.1.1 wolframalpha-5.0.0
Note: you may need to restart the kernel to use updated packages.
pip install twilio
Collecting twilio
  Downloading twilio-7.6.0-py2.py3-none-any.whl (1.4 MB)
Requirement already satisfied: pytz in c:\users\adity\anaconda3\lib\site-packages (from twilio) (2021.3)
Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in c:\users\adity\anaconda3\lib\site-packages (from twilio) (2.1.0)
Requirement already satisfied: requests>=2.0.0 in c:\users\adity\anaconda3\lib\site-packages (from twilio) (2.26.0)
Requirement already satisfied: idna<4,>=2.5 in c:\users\adity\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (3.2)
Requirement already satisfied: certifi>=2017.4.17 in c:\users\adity\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2021.10.8)
Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\adity\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (1.26.7)
Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\adity\anaconda3\lib\site-packages (from requests>=2.0.0->twilio) (2.0.4)
Installing collected packages: twilio
Successfully installed twilio-7.6.0
Note: you may need to restart the kernel to use updated packages.
pip install beautifulsoup4
Requirement already satisfied: beautifulsoup4 in c:\users\adity\anaconda3\lib\site-packages (4.10.0)
Requirement already satisfied: soupsieve>1.2 in c:\users\adity\anaconda3\lib\site-packages (from beautifulsoup4) (2.2.1)
Note: you may need to restart the kernel to use updated packages.
pip install ecapture
Collecting ecapture
  Using cached ecapture-0.1.8-py3-none-any.whl (6.8 kB)
Collecting opencv-python
  Using cached opencv_python-4.5.5.62-cp36-abi3-win_amd64.whl (35.4 MB)Note: you may need to restart the kernel to use updated packages.
Collecting scikit-image==0.14.2
  Using cached scikit-image-0.14.2.tar.gz (27.8 MB)
  Installing build dependencies: started
  Installing build dependencies: finished with status 'done'

  Getting requirements to build wheel: started
  Getting requirements to build wheel: finished with status 'done'
    Preparing wheel metadata: started
  ERROR: Command errored out with exit status 1:
   command: 'C:\Users\adity\anaconda3\python.exe' 'C:\Users\adity\anaconda3\lib\site-packages\pip\_vendor\pep517\in_process\_in_process.py' build_wheel 'C:\Users\adity\AppData\Local\Temp\tmph8l13tl8'
       cwd: C:\Users\adity\AppData\Local\Temp\pip-install-ln8rdfkg\scikit-image_895f8c1e9ed14a618dd13f1920e2337f
  Complete output (456 lines):
  Partial import of skimage during the build process.
  running bdist_wheel
  running build
  running config_cc
  INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
  running config_fc
  INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
  running build_src
  INFO: build_src
  INFO: building extension "skimage._shared.geometry" sources
  INFO: building extension "skimage._shared.transform" sources
  INFO: building extension "skimage._shared.interpolation" sources
  INFO: building extension "skimage.draw._draw" sources
  INFO: building extension "skimage.feature.corner_cy" sources
  INFO: building extension "skimage.feature.censure_cy" sources
  INFO: building extension "skimage.feature.orb_cy" sources
  INFO: building extension "skimage.feature.brief_cy" sources
  INFO: building extension "skimage.feature._texture" sources
  INFO: building extension "skimage.feature._hessian_det_appx" sources
  INFO: building extension "skimage.feature._hoghistogram" sources
  INFO: building extension "skimage.feature._haar" sources
  INFO: building extension "skimage.restoration._unwrap_1d" sources
  INFO: building extension "skimage.restoration._unwrap_2d" sources
  INFO: building extension "skimage.restoration._unwrap_3d" sources
  INFO: building extension "skimage.restoration._denoise_cy" sources
  INFO: building extension "skimage.restoration._nl_means_denoising" sources
  INFO: building extension "skimage.filters._ctmf" sources
  INFO: building extension "skimage.filters.rank.core_cy" sources
  INFO: building extension "skimage.filters.rank.generic_cy" sources
  INFO: building extension "skimage.filters.rank.percentile_cy" sources
  INFO: building extension "skimage.filters.rank.bilateral_cy" sources
  INFO: building extension "skimage.future.graph._ncut_cy" sources
  INFO: building extension "skimage.graph._spath" sources
  INFO: building extension "skimage.graph._mcp" sources
  INFO: building extension "skimage.graph.heap" sources
  INFO: building extension "skimage.io._plugins._colormixer" sources
  INFO: building extension "skimage.io._plugins._histograms" sources
  INFO: building extension "skimage.measure._ccomp" sources
  INFO: building extension "skimage.measure._find_contours_cy" sources
  INFO: building extension "skimage.measure._moments_cy" sources
  INFO: building extension "skimage.measure._marching_cubes_classic_cy" sources
  INFO: building extension "skimage.measure._marching_cubes_lewiner_cy" sources
  INFO: building extension "skimage.measure._pnpoly" sources
  INFO: building extension "skimage.morphology._watershed" sources
  INFO: building extension "skimage.morphology._skeletonize_cy" sources
  INFO: building extension "skimage.morphology._convex_hull" sources
  INFO: building extension "skimage.morphology._greyreconstruct" sources
  INFO: building extension "skimage.morphology._skeletonize_3d_cy" sources
  INFO: building extension "skimage.morphology._extrema_cy" sources
  INFO: building extension "skimage.transform._hough_transform" sources
  INFO: building extension "skimage.transform._warps_cy" sources
  INFO: building extension "skimage.transform._radon_transform" sources
  INFO: building extension "skimage.transform._seam_carving" sources
  INFO: building extension "skimage.segmentation._felzenszwalb_cy" sources
  INFO: building extension "skimage.segmentation._quickshift_cy" sources
  INFO: building extension "skimage.segmentation._slic" sources
  INFO: building extension "skimage.external.tifffile._tifffile" sources
  INFO: building data_files sources
  INFO: build_src: building npy-pkg config files
  running build_py
  creating build
  creating build\lib.win-amd64-3.9
  creating build\lib.win-amd64-3.9\skimage
  copying skimage\setup.py -> build\lib.win-amd64-3.9\skimage
  copying skimage\_build.py -> build\lib.win-amd64-3.9\skimage
  copying skimage\__init__.py -> build\lib.win-amd64-3.9\skimage
  creating build\lib.win-amd64-3.9\skimage\color
  copying skimage\color\adapt_rgb.py -> build\lib.win-amd64-3.9\skimage\color
  copying skimage\color\colorconv.py -> build\lib.win-amd64-3.9\skimage\color
  copying skimage\color\colorlabel.py -> build\lib.win-amd64-3.9\skimage\color
  copying skimage\color\delta_e.py -> build\lib.win-amd64-3.9\skimage\color
  copying skimage\color\rgb_colors.py -> build\lib.win-amd64-3.9\skimage\color
  copying skimage\color\__init__.py -> build\lib.win-amd64-3.9\skimage\color
  creating build\lib.win-amd64-3.9\skimage\data
  copying skimage\data\_binary_blobs.py -> build\lib.win-amd64-3.9\skimage\data
  copying skimage\data\__init__.py -> build\lib.win-amd64-3.9\skimage\data
  creating build\lib.win-amd64-3.9\skimage\draw
  copying skimage\draw\draw.py -> build\lib.win-amd64-3.9\skimage\draw
  copying skimage\draw\draw3d.py -> build\lib.win-amd64-3.9\skimage\draw
  copying skimage\draw\setup.py -> build\lib.win-amd64-3.9\skimage\draw
  copying skimage\draw\_random_shapes.py -> build\lib.win-amd64-3.9\skimage\draw
  copying skimage\draw\__init__.py -> build\lib.win-amd64-3.9\skimage\draw
  creating build\lib.win-amd64-3.9\skimage\exposure
  copying skimage\exposure\exposure.py -> build\lib.win-amd64-3.9\skimage\exposure
  copying skimage\exposure\setup.py -> build\lib.win-amd64-3.9\skimage\exposure
  copying skimage\exposure\_adapthist.py -> build\lib.win-amd64-3.9\skimage\exposure
  copying skimage\exposure\__init__.py -> build\lib.win-amd64-3.9\skimage\exposure
  creating build\lib.win-amd64-3.9\skimage\external
  copying skimage\external\setup.py -> build\lib.win-amd64-3.9\skimage\external
  copying skimage\external\test_tifffile.py -> build\lib.win-amd64-3.9\skimage\external
  copying skimage\external\__init__.py -> build\lib.win-amd64-3.9\skimage\external
  creating build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\blob.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\brief.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\censure.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\corner.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\haar.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\match.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\orb.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\peak.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\register_translation.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\setup.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\template.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\texture.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\util.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\_canny.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\_daisy.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\_hog.py -> build\lib.win-amd64-3.9\skimage\feature
  copying skimage\feature\__init__.py -> build\lib.win-amd64-3.9\skimage\feature
  creating build\lib.win-amd64-3.9\skimage\filters
  copying skimage\filters\edges.py -> build\lib.win-amd64-3.9\skimage\filters
  copying skimage\filters\lpi_filter.py -> build\lib.win-amd64-3.9\skimage\filters
  copying skimage\filters\setup.py -> build\lib.win-amd64-3.9\skimage\filters
  copying skimage\filters\thresholding.py -> build\lib.win-amd64-3.9\skimage\filters
  copying skimage\filters\_frangi.py -> build\lib.win-amd64-3.9\skimage\filters
  copying skimage\filters\_gabor.py -> build\lib.win-amd64-3.9\skimage\filters
  copying skimage\filters\_gaussian.py -> build\lib.win-amd64-3.9\skimage\filters
  copying skimage\filters\_rank_order.py -> build\lib.win-amd64-3.9\skimage\filters
  copying skimage\filters\__init__.py -> build\lib.win-amd64-3.9\skimage\filters
  creating build\lib.win-amd64-3.9\skimage\future
  copying skimage\future\manual_segmentation.py -> build\lib.win-amd64-3.9\skimage\future
  copying skimage\future\setup.py -> build\lib.win-amd64-3.9\skimage\future
  copying skimage\future\__init__.py -> build\lib.win-amd64-3.9\skimage\future
  creating build\lib.win-amd64-3.9\skimage\graph
  copying skimage\graph\mcp.py -> build\lib.win-amd64-3.9\skimage\graph
  copying skimage\graph\setup.py -> build\lib.win-amd64-3.9\skimage\graph
  copying skimage\graph\spath.py -> build\lib.win-amd64-3.9\skimage\graph
  copying skimage\graph\__init__.py -> build\lib.win-amd64-3.9\skimage\graph
  creating build\lib.win-amd64-3.9\skimage\io
  copying skimage\io\collection.py -> build\lib.win-amd64-3.9\skimage\io
  copying skimage\io\manage_plugins.py -> build\lib.win-amd64-3.9\skimage\io
  copying skimage\io\setup.py -> build\lib.win-amd64-3.9\skimage\io
  copying skimage\io\sift.py -> build\lib.win-amd64-3.9\skimage\io
  copying skimage\io\util.py -> build\lib.win-amd64-3.9\skimage\io
  copying skimage\io\_image_stack.py -> build\lib.win-amd64-3.9\skimage\io
  copying skimage\io\_io.py -> build\lib.win-amd64-3.9\skimage\io
  copying skimage\io\__init__.py -> build\lib.win-amd64-3.9\skimage\io
  creating build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\block.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\entropy.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\fit.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\pnpoly.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\profile.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\setup.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\simple_metrics.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\_find_contours.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\_label.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\_marching_cubes_classic.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\_marching_cubes_lewiner.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\_marching_cubes_lewiner_luts.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\_moments.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\_polygon.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\_regionprops.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\_structural_similarity.py -> build\lib.win-amd64-3.9\skimage\measure
  copying skimage\measure\__init__.py -> build\lib.win-amd64-3.9\skimage\measure
  creating build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\binary.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\convex_hull.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\extrema.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\grey.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\greyreconstruct.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\misc.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\selem.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\setup.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\watershed.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\_skeletonize.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\_skeletonize_3d.py -> build\lib.win-amd64-3.9\skimage\morphology
  copying skimage\morphology\__init__.py -> build\lib.win-amd64-3.9\skimage\morphology
  creating build\lib.win-amd64-3.9\skimage\novice
  copying skimage\novice\_novice.py -> build\lib.win-amd64-3.9\skimage\novice
  copying skimage\novice\__init__.py -> build\lib.win-amd64-3.9\skimage\novice
  creating build\lib.win-amd64-3.9\skimage\restoration
  copying skimage\restoration\deconvolution.py -> build\lib.win-amd64-3.9\skimage\restoration
  copying skimage\restoration\inpaint.py -> build\lib.win-amd64-3.9\skimage\restoration
  copying skimage\restoration\non_local_means.py -> build\lib.win-amd64-3.9\skimage\restoration
  copying skimage\restoration\setup.py -> build\lib.win-amd64-3.9\skimage\restoration
  copying skimage\restoration\uft.py -> build\lib.win-amd64-3.9\skimage\restoration
  copying skimage\restoration\unwrap.py -> build\lib.win-amd64-3.9\skimage\restoration
  copying skimage\restoration\_cycle_spin.py -> build\lib.win-amd64-3.9\skimage\restoration
  copying skimage\restoration\_denoise.py -> build\lib.win-amd64-3.9\skimage\restoration
  copying skimage\restoration\__init__.py -> build\lib.win-amd64-3.9\skimage\restoration
  creating build\lib.win-amd64-3.9\skimage\scripts
  copying skimage\scripts\skivi.py -> build\lib.win-amd64-3.9\skimage\scripts
  copying skimage\scripts\__init__.py -> build\lib.win-amd64-3.9\skimage\scripts
  creating build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\active_contour_model.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\boundaries.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\morphsnakes.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\random_walker_segmentation.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\setup.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\slic_superpixels.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\_chan_vese.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\_clear_border.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\_felzenszwalb.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\_join.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\_quickshift.py -> build\lib.win-amd64-3.9\skimage\segmentation
  copying skimage\segmentation\__init__.py -> build\lib.win-amd64-3.9\skimage\segmentation
  creating build\lib.win-amd64-3.9\skimage\transform
  copying skimage\transform\finite_radon_transform.py -> build\lib.win-amd64-3.9\skimage\transform
  copying skimage\transform\hough_transform.py -> build\lib.win-amd64-3.9\skimage\transform
  copying skimage\transform\integral.py -> build\lib.win-amd64-3.9\skimage\transform
  copying skimage\transform\pyramids.py -> build\lib.win-amd64-3.9\skimage\transform
  copying skimage\transform\radon_transform.py -> build\lib.win-amd64-3.9\skimage\transform
  copying skimage\transform\seam_carving.py -> build\lib.win-amd64-3.9\skimage\transform
  copying skimage\transform\setup.py -> build\lib.win-amd64-3.9\skimage\transform
  copying skimage\transform\_geometric.py -> build\lib.win-amd64-3.9\skimage\transform
  copying skimage\transform\_warps.py -> build\lib.win-amd64-3.9\skimage\transform
  copying skimage\transform\__init__.py -> build\lib.win-amd64-3.9\skimage\transform
  creating build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\apply_parallel.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\arraycrop.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\colormap.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\dtype.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\lookfor.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\noise.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\shape.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\unique.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\_invert.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\_montage.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\_regular_grid.py -> build\lib.win-amd64-3.9\skimage\util
  copying skimage\util\__init__.py -> build\lib.win-amd64-3.9\skimage\util
  creating build\lib.win-amd64-3.9\skimage\viewer
  copying skimage\viewer\qt.py -> build\lib.win-amd64-3.9\skimage\viewer
  copying skimage\viewer\__init__.py -> build\lib.win-amd64-3.9\skimage\viewer
  creating build\lib.win-amd64-3.9\skimage\_shared
  copying skimage\_shared\setup.py -> build\lib.win-amd64-3.9\skimage\_shared
  copying skimage\_shared\testing.py -> build\lib.win-amd64-3.9\skimage\_shared
  copying skimage\_shared\utils.py -> build\lib.win-amd64-3.9\skimage\_shared
  copying skimage\_shared\version_requirements.py -> build\lib.win-amd64-3.9\skimage\_shared
  copying skimage\_shared\_geometry.py -> build\lib.win-amd64-3.9\skimage\_shared
  copying skimage\_shared\_tempfile.py -> build\lib.win-amd64-3.9\skimage\_shared
  copying skimage\_shared\_warnings.py -> build\lib.win-amd64-3.9\skimage\_shared
  copying skimage\_shared\__init__.py -> build\lib.win-amd64-3.9\skimage\_shared
  creating build\lib.win-amd64-3.9\skimage\color\tests
  copying skimage\color\tests\test_adapt_rgb.py -> build\lib.win-amd64-3.9\skimage\color\tests
  copying skimage\color\tests\test_colorconv.py -> build\lib.win-amd64-3.9\skimage\color\tests
  copying skimage\color\tests\test_colorlabel.py -> build\lib.win-amd64-3.9\skimage\color\tests
  copying skimage\color\tests\test_delta_e.py -> build\lib.win-amd64-3.9\skimage\color\tests
  copying skimage\color\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\color\tests
  creating build\lib.win-amd64-3.9\skimage\data\tests
  copying skimage\data\tests\test_data.py -> build\lib.win-amd64-3.9\skimage\data\tests
  copying skimage\data\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\data\tests
  creating build\lib.win-amd64-3.9\skimage\draw\tests
  copying skimage\draw\tests\test_draw.py -> build\lib.win-amd64-3.9\skimage\draw\tests
  copying skimage\draw\tests\test_draw3d.py -> build\lib.win-amd64-3.9\skimage\draw\tests
  copying skimage\draw\tests\test_random_shapes.py -> build\lib.win-amd64-3.9\skimage\draw\tests
  copying skimage\draw\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\draw\tests
  creating build\lib.win-amd64-3.9\skimage\exposure\tests
  copying skimage\exposure\tests\test_exposure.py -> build\lib.win-amd64-3.9\skimage\exposure\tests
  copying skimage\exposure\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\exposure\tests
  creating build\lib.win-amd64-3.9\skimage\external\tifffile
  copying skimage\external\tifffile\tifffile.py -> build\lib.win-amd64-3.9\skimage\external\tifffile
  copying skimage\external\tifffile\__init__.py -> build\lib.win-amd64-3.9\skimage\external\tifffile
  creating build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_blob.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_brief.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_canny.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_censure.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_corner.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_daisy.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_haar.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_hog.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_match.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_orb.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_peak.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_register_translation.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_template.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_texture.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\test_util.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  copying skimage\feature\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\feature\tests
  creating build\lib.win-amd64-3.9\skimage\filters\rank
  copying skimage\filters\rank\bilateral.py -> build\lib.win-amd64-3.9\skimage\filters\rank
  copying skimage\filters\rank\generic.py -> build\lib.win-amd64-3.9\skimage\filters\rank
  copying skimage\filters\rank\_percentile.py -> build\lib.win-amd64-3.9\skimage\filters\rank
  copying skimage\filters\rank\__init__.py -> build\lib.win-amd64-3.9\skimage\filters\rank
  creating build\lib.win-amd64-3.9\skimage\filters\tests
  copying skimage\filters\tests\test_edges.py -> build\lib.win-amd64-3.9\skimage\filters\tests
  copying skimage\filters\tests\test_frangi.py -> build\lib.win-amd64-3.9\skimage\filters\tests
  copying skimage\filters\tests\test_gabor.py -> build\lib.win-amd64-3.9\skimage\filters\tests
  copying skimage\filters\tests\test_gaussian.py -> build\lib.win-amd64-3.9\skimage\filters\tests
  copying skimage\filters\tests\test_lpi_filter.py -> build\lib.win-amd64-3.9\skimage\filters\tests
  copying skimage\filters\tests\test_median.py -> build\lib.win-amd64-3.9\skimage\filters\tests
  copying skimage\filters\tests\test_thresholding.py -> build\lib.win-amd64-3.9\skimage\filters\tests
  copying skimage\filters\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\filters\tests
  creating build\lib.win-amd64-3.9\skimage\filters\rank\tests
  copying skimage\filters\rank\tests\test_rank.py -> build\lib.win-amd64-3.9\skimage\filters\rank\tests
  copying skimage\filters\rank\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\filters\rank\tests
  creating build\lib.win-amd64-3.9\skimage\future\graph
  copying skimage\future\graph\graph_cut.py -> build\lib.win-amd64-3.9\skimage\future\graph
  copying skimage\future\graph\graph_merge.py -> build\lib.win-amd64-3.9\skimage\future\graph
  copying skimage\future\graph\rag.py -> build\lib.win-amd64-3.9\skimage\future\graph
  copying skimage\future\graph\setup.py -> build\lib.win-amd64-3.9\skimage\future\graph
  copying skimage\future\graph\_ncut.py -> build\lib.win-amd64-3.9\skimage\future\graph
  copying skimage\future\graph\__init__.py -> build\lib.win-amd64-3.9\skimage\future\graph
  creating build\lib.win-amd64-3.9\skimage\graph\tests
  copying skimage\graph\tests\test_anisotropy.py -> build\lib.win-amd64-3.9\skimage\graph\tests
  copying skimage\graph\tests\test_connect.py -> build\lib.win-amd64-3.9\skimage\graph\tests
  copying skimage\graph\tests\test_flexible.py -> build\lib.win-amd64-3.9\skimage\graph\tests
  copying skimage\graph\tests\test_heap.py -> build\lib.win-amd64-3.9\skimage\graph\tests
  copying skimage\graph\tests\test_mcp.py -> build\lib.win-amd64-3.9\skimage\graph\tests
  copying skimage\graph\tests\test_spath.py -> build\lib.win-amd64-3.9\skimage\graph\tests
  copying skimage\graph\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\graph\tests
  creating build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_collection.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_colormixer.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_fits.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_histograms.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_imageio.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_imread.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_io.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_mpl_imshow.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_multi_image.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_pil.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_plugin.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_plugin_util.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_sift.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_simpleitk.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\test_tifffile.py -> build\lib.win-amd64-3.9\skimage\io\tests
  copying skimage\io\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\io\tests
  creating build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\fits_plugin.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\gdal_plugin.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\gtk_plugin.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\imageio_plugin.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\imread_plugin.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\matplotlib_plugin.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\pil_plugin.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\qt_plugin.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\q_color_mixer.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\q_histogram.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\simpleitk_plugin.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\skivi.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\tifffile_plugin.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\util.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  copying skimage\io\_plugins\__init__.py -> build\lib.win-amd64-3.9\skimage\io\_plugins
  creating build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_block.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_entropy.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_find_contours.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_fit.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_marching_cubes.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_moments.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_pnpoly.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_polygon.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_profile.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_regionprops.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_simple_metrics.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\test_structural_similarity.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  copying skimage\measure\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\measure\tests
  creating build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_binary.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_ccomp.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_convex_hull.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_extrema.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_grey.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_misc.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_reconstruction.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_selem.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_skeletonize.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_skeletonize_3d.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\test_watershed.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  copying skimage\morphology\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\morphology\tests
  creating build\lib.win-amd64-3.9\skimage\novice\tests
  copying skimage\novice\tests\test_novice.py -> build\lib.win-amd64-3.9\skimage\novice\tests
  copying skimage\novice\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\novice\tests
  creating build\lib.win-amd64-3.9\skimage\restoration\tests
  copying skimage\restoration\tests\test_denoise.py -> build\lib.win-amd64-3.9\skimage\restoration\tests
  copying skimage\restoration\tests\test_inpaint.py -> build\lib.win-amd64-3.9\skimage\restoration\tests
  copying skimage\restoration\tests\test_restoration.py -> build\lib.win-amd64-3.9\skimage\restoration\tests
  copying skimage\restoration\tests\test_unwrap.py -> build\lib.win-amd64-3.9\skimage\restoration\tests
  copying skimage\restoration\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\restoration\tests
  creating build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\test_active_contour_model.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\test_boundaries.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\test_chan_vese.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\test_clear_border.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\test_felzenszwalb.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\test_join.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\test_morphsnakes.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\test_quickshift.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\test_random_walker.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\test_slic.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  copying skimage\segmentation\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\segmentation\tests
  creating build\lib.win-amd64-3.9\skimage\transform\tests
  copying skimage\transform\tests\test_finite_radon_transform.py -> build\lib.win-amd64-3.9\skimage\transform\tests
  copying skimage\transform\tests\test_geometric.py -> build\lib.win-amd64-3.9\skimage\transform\tests
  copying skimage\transform\tests\test_hough_transform.py -> build\lib.win-amd64-3.9\skimage\transform\tests
  copying skimage\transform\tests\test_integral.py -> build\lib.win-amd64-3.9\skimage\transform\tests
  copying skimage\transform\tests\test_pyramids.py -> build\lib.win-amd64-3.9\skimage\transform\tests
  copying skimage\transform\tests\test_radon_transform.py -> build\lib.win-amd64-3.9\skimage\transform\tests
  copying skimage\transform\tests\test_seam_carving.py -> build\lib.win-amd64-3.9\skimage\transform\tests
  copying skimage\transform\tests\test_warps.py -> build\lib.win-amd64-3.9\skimage\transform\tests
  copying skimage\transform\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\transform\tests
  creating build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\test_apply_parallel.py -> build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\test_arraycrop.py -> build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\test_arraypad.py -> build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\test_dtype.py -> build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\test_invert.py -> build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\test_montage.py -> build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\test_random_noise.py -> build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\test_regular_grid.py -> build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\test_shape.py -> build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\test_unique_rows.py -> build\lib.win-amd64-3.9\skimage\util\tests
  copying skimage\util\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\util\tests
  creating build\lib.win-amd64-3.9\skimage\viewer\canvastools
  copying skimage\viewer\canvastools\base.py -> build\lib.win-amd64-3.9\skimage\viewer\canvastools
  copying skimage\viewer\canvastools\linetool.py -> build\lib.win-amd64-3.9\skimage\viewer\canvastools
  copying skimage\viewer\canvastools\painttool.py -> build\lib.win-amd64-3.9\skimage\viewer\canvastools
  copying skimage\viewer\canvastools\recttool.py -> build\lib.win-amd64-3.9\skimage\viewer\canvastools
  copying skimage\viewer\canvastools\__init__.py -> build\lib.win-amd64-3.9\skimage\viewer\canvastools
  creating build\lib.win-amd64-3.9\skimage\viewer\plugins
  copying skimage\viewer\plugins\base.py -> build\lib.win-amd64-3.9\skimage\viewer\plugins
  copying skimage\viewer\plugins\canny.py -> build\lib.win-amd64-3.9\skimage\viewer\plugins
  copying skimage\viewer\plugins\color_histogram.py -> build\lib.win-amd64-3.9\skimage\viewer\plugins
  copying skimage\viewer\plugins\crop.py -> build\lib.win-amd64-3.9\skimage\viewer\plugins
  copying skimage\viewer\plugins\labelplugin.py -> build\lib.win-amd64-3.9\skimage\viewer\plugins
  copying skimage\viewer\plugins\lineprofile.py -> build\lib.win-amd64-3.9\skimage\viewer\plugins
  copying skimage\viewer\plugins\measure.py -> build\lib.win-amd64-3.9\skimage\viewer\plugins
  copying skimage\viewer\plugins\overlayplugin.py -> build\lib.win-amd64-3.9\skimage\viewer\plugins
  copying skimage\viewer\plugins\plotplugin.py -> build\lib.win-amd64-3.9\skimage\viewer\plugins
  copying skimage\viewer\plugins\__init__.py -> build\lib.win-amd64-3.9\skimage\viewer\plugins
  creating build\lib.win-amd64-3.9\skimage\viewer\tests
  copying skimage\viewer\tests\test_plugins.py -> build\lib.win-amd64-3.9\skimage\viewer\tests
  copying skimage\viewer\tests\test_tools.py -> build\lib.win-amd64-3.9\skimage\viewer\tests
  copying skimage\viewer\tests\test_utils.py -> build\lib.win-amd64-3.9\skimage\viewer\tests
  copying skimage\viewer\tests\test_viewer.py -> build\lib.win-amd64-3.9\skimage\viewer\tests
  copying skimage\viewer\tests\test_widgets.py -> build\lib.win-amd64-3.9\skimage\viewer\tests
  copying skimage\viewer\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\viewer\tests
  creating build\lib.win-amd64-3.9\skimage\viewer\utils
  copying skimage\viewer\utils\canvas.py -> build\lib.win-amd64-3.9\skimage\viewer\utils
  copying skimage\viewer\utils\core.py -> build\lib.win-amd64-3.9\skimage\viewer\utils
  copying skimage\viewer\utils\dialogs.py -> build\lib.win-amd64-3.9\skimage\viewer\utils
  copying skimage\viewer\utils\__init__.py -> build\lib.win-amd64-3.9\skimage\viewer\utils
  creating build\lib.win-amd64-3.9\skimage\viewer\viewers
  copying skimage\viewer\viewers\core.py -> build\lib.win-amd64-3.9\skimage\viewer\viewers
  copying skimage\viewer\viewers\__init__.py -> build\lib.win-amd64-3.9\skimage\viewer\viewers
  creating build\lib.win-amd64-3.9\skimage\viewer\widgets
    Preparing wheel metadata: finished with status 'done'
Requirement already satisfied: six>=1.10.0 in c:\users\adity\anaconda3\lib\site-packages (from scikit-image==0.14.2->ecapture) (1.16.0)
Requirement already satisfied: PyWavelets>=0.4.0 in c:\users\adity\anaconda3\lib\site-packages (from scikit-image==0.14.2->ecapture) (1.1.1)
Requirement already satisfied: networkx>=1.8 in c:\users\adity\anaconda3\lib\site-packages (from scikit-image==0.14.2->ecapture) (2.6.3)
Requirement already satisfied: scipy>=0.17.0 in c:\users\adity\anaconda3\lib\site-packages (from scikit-image==0.14.2->ecapture) (1.7.1)
Requirement already satisfied: cloudpickle>=0.2.1 in c:\users\adity\anaconda3\lib\site-packages (from scikit-image==0.14.2->ecapture) (2.0.0)
Requirement already satisfied: matplotlib>=2.0.0 in c:\users\adity\anaconda3\lib\site-packages (from scikit-image==0.14.2->ecapture) (3.4.3)
Requirement already satisfied: dask[array]>=1.0.0 in c:\users\adity\anaconda3\lib\site-packages (from scikit-image==0.14.2->ecapture) (2021.10.0)
Requirement already satisfied: pillow>=4.3.0 in c:\users\adity\anaconda3\lib\site-packages (from scikit-image==0.14.2->ecapture) (8.4.0)
Requirement already satisfied: fsspec>=0.6.0 in c:\users\adity\anaconda3\lib\site-packages (from dask[array]>=1.0.0->scikit-image==0.14.2->ecapture) (2021.10.1)
Requirement already satisfied: packaging>=20.0 in c:\users\adity\anaconda3\lib\site-packages (from dask[array]>=1.0.0->scikit-image==0.14.2->ecapture) (21.0)
Requirement already satisfied: partd>=0.3.10 in c:\users\adity\anaconda3\lib\site-packages (from dask[array]>=1.0.0->scikit-image==0.14.2->ecapture) (1.2.0)
Requirement already satisfied: pyyaml in c:\users\adity\anaconda3\lib\site-packages (from dask[array]>=1.0.0->scikit-image==0.14.2->ecapture) (6.0)
Requirement already satisfied: toolz>=0.8.2 in c:\users\adity\anaconda3\lib\site-packages (from dask[array]>=1.0.0->scikit-image==0.14.2->ecapture) (0.11.1)
Requirement already satisfied: numpy>=1.18 in c:\users\adity\anaconda3\lib\site-packages (from dask[array]>=1.0.0->scikit-image==0.14.2->ecapture) (1.20.3)
Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\adity\anaconda3\lib\site-packages (from matplotlib>=2.0.0->scikit-image==0.14.2->ecapture) (1.3.1)
Requirement already satisfied: pyparsing>=2.2.1 in c:\users\adity\anaconda3\lib\site-packages (from matplotlib>=2.0.0->scikit-image==0.14.2->ecapture) (3.0.4)
Requirement already satisfied: cycler>=0.10 in c:\users\adity\anaconda3\lib\site-packages (from matplotlib>=2.0.0->scikit-image==0.14.2->ecapture) (0.10.0)
Requirement already satisfied: python-dateutil>=2.7 in c:\users\adity\anaconda3\lib\site-packages (from matplotlib>=2.0.0->scikit-image==0.14.2->ecapture) (2.8.2)
Requirement already satisfied: locket in c:\users\adity\anaconda3\lib\site-packages\locket-0.2.1-py3.9.egg (from partd>=0.3.10->dask[array]>=1.0.0->scikit-image==0.14.2->ecapture) (0.2.1)
Building wheels for collected packages: scikit-image
  Building wheel for scikit-image (PEP 517): started
  Building wheel for scikit-image (PEP 517): finished with status 'error'
Failed to build scikit-image
  copying skimage\viewer\widgets\core.py -> build\lib.win-amd64-3.9\skimage\viewer\widgets
  copying skimage\viewer\widgets\history.py -> build\lib.win-amd64-3.9\skimage\viewer\widgets
  copying skimage\viewer\widgets\__init__.py -> build\lib.win-amd64-3.9\skimage\viewer\widgets
  creating build\lib.win-amd64-3.9\skimage\_shared\tests
  copying skimage\_shared\tests\test_geometry.py -> build\lib.win-amd64-3.9\skimage\_shared\tests
  copying skimage\_shared\tests\test_interpolation.py -> build\lib.win-amd64-3.9\skimage\_shared\tests
  copying skimage\_shared\tests\test_safe_as_int.py -> build\lib.win-amd64-3.9\skimage\_shared\tests
  copying skimage\_shared\tests\test_testing.py -> build\lib.win-amd64-3.9\skimage\_shared\tests
  copying skimage\_shared\tests\test_utils.py -> build\lib.win-amd64-3.9\skimage\_shared\tests
  copying skimage\_shared\tests\test_version_requirements.py -> build\lib.win-amd64-3.9\skimage\_shared\tests
  copying skimage\_shared\tests\__init__.py -> build\lib.win-amd64-3.9\skimage\_shared\tests
  running build_ext
  INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
  INFO: customize MSVCCompiler
  INFO: customize MSVCCompiler using build_ext
  INFO: CCompilerOpt.cc_test_flags[1021] : testing flags (/O2)
  error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
  INFO: CCompilerOpt.cache_flush[817] : write cache to path -> C:\Users\adity\AppData\Local\Temp\pip-install-ln8rdfkg\scikit-image_895f8c1e9ed14a618dd13f1920e2337f\build\temp.win-amd64-3.9\Release\ccompiler_opt_cache_ext.py
  ----------------------------------------
  ERROR: Failed building wheel for scikit-image
ERROR: Could not build wheels for scikit-image which use PEP 517 and cannot be installed directly
